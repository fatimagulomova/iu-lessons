# %% [markdown]
# <a href="https://www.kaggle.com/code/fotimakhongulomova/simple-reccurent-neural-network-simplernn?scriptVersionId=160970013" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Import Notebook

# %%
# %%capture --no-display

from keras.datasets import imdb
from keras.preprocessing import sequence
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import *
import matplotlib.pyplot as plt
# Out:
# 2024-01-30 06:12:01.854310: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-30 06:12:01.854436: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-30 06:12:02.035197: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Constants
max_feat = 10000
max_len = 500
batch_size = 32

# %% [markdown]
# ## Load the Data

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=max_feat)

# shape of input train and test data
X_train = pad_sequences(X_train, maxlen=max_len)
X_test = pad_sequences(X_test, maxlen=max_len)

print('Shape of input training data:', X_train.shape)
print('Shape of input test data:', X_test.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 1s 0us/step
# Shape of input training data: (25000, 500)
# Shape of input test data: (25000, 500)

# %% [markdown]
# ## Training the Model with Embedding and SimpleRNN layers

# %%
network = Sequential()
network.add(Embedding(max_feat, 32))
network.add(SimpleRNN(32))
network.add(Dense(1, activation='sigmoid'))

network.compile(optimizer='rmsprop', metrics=['acc'], loss='binary_crossentropy',)
history = network.fit(X_train, y_train, epochs=10, batch_size=128, validation_split=0.2)
# Out:
# Epoch 1/10
# 157/157 [==============================] - 22s 133ms/step - loss: 0.5867 - acc: 0.6768 - val_loss: 0.4825 - val_acc: 0.7728
# Epoch 2/10
# 157/157 [==============================] - 21s 131ms/step - loss: 0.3807 - acc: 0.8386 - val_loss: 0.4461 - val_acc: 0.7962
# Epoch 3/10
# 157/157 [==============================] - 20s 129ms/step - loss: 0.3035 - acc: 0.8787 - val_loss: 0.5176 - val_acc: 0.7912
# Epoch 4/10
# 157/157 [==============================] - 20s 130ms/step - loss: 0.2445 - acc: 0.9050 - val_loss: 0.3840 - val_acc: 0.8302
# Epoch 5/10
# 157/157 [==============================] - 20s 129ms/step - loss: 0.2058 - acc: 0.9208 - val_loss: 0.3979 - val_acc: 0.8568
# Epoch 6/10
# 157/157 [==============================] - 20s 126ms/step - loss: 0.1574 - acc: 0.9425 - val_loss: 0.4990 - val_acc: 0.7838
# Epoch 7/10
# 157/157 [==============================] - 20s 129ms/step - loss: 0.1171 - acc: 0.9586 - val_loss: 0.4424 - val_acc: 0.8508
# Epoch 8/10
# 157/157 [==============================] - 20s 127ms/step - loss: 0.0801 - acc: 0.9739 - val_loss: 0.5063 - val_acc: 0.8334
# Epoch 9/10
# 157/157 [==============================] - 20s 127ms/step - loss: 0.0603 - acc: 0.9811 - val_loss: 0.5453 - val_acc: 0.8180
# Epoch 10/10
# 157/157 [==============================] - 20s 128ms/step - loss: 0.0386 - acc: 0.9880 - val_loss: 0.7549 - val_acc: 0.7528

# %% [markdown]
# ## Displaying the results

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 3))

epochs = range(1, len(acc) + 1)
ax1.plot(epochs, acc, 'o', label='Training accuracy')
ax1.plot(epochs, val_acc, label='Validation accuracy')
ax1.set_title('Training and validation accuracy')
ax1.legend()

ax2.plot(epochs, loss, 'o', label='Training loss')
ax2.plot(epochs, val_loss, label='Validation loss')
ax2.set_title('Training and validation loss')
ax2.legend()
